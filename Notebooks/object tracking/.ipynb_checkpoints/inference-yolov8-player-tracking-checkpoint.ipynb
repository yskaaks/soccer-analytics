# %% [markdown]
# # Soccer player detection & tracking using YOLOv8 (Trackers comparison)

# %% [markdown]
# The following code implement and compares the performance of the trackers integrated by default on YOLOv8
# - Botsort
# - Bytetrack
#
# As well as the external tracker:
# - Norfair

# %% [markdown]
# # Required libraries

# %%
from IPython.display import Video as disp_vid
from tqdm.notebook import tqdm
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np
from norfair import Detection, Tracker, Video, draw_points

# %% [markdown]
# # Paths for the model, video, and output videos

# %%
YOLO_MODEL = "../../Models/pretrained-yolov8-soccer.pt"
VIDEO_PATH = "../../Datasets/object tracking videos/test_soccer_video_2.mp4"
OUTPUT_BOTSORT_VIDEO_PATH = 'outputs/output_botsort_video_2.mp4'
OUTPUT_BYTETRACK_VIDEO_PATH = 'outputs/output_bytetrack_video_2.mp4'
OUTPUT_NORFAIR_VIDEO_PATH = 'outputs/output_norfair_video_2.mp4'

# %% [markdown]
# # Load pretrained YOLO model

# %%
model = YOLO(YOLO_MODEL)

# %% [markdown]
# # Display the input video

# %%
# Display a local video file
disp_vid(VIDEO_PATH, width=640, height=360)
# Out:
# <video src="../../Datasets/object tracking videos/test_soccer_video_2.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # Define useful processing and visualizations functions

# %%
def yolo_pred_to_dict(yolo_results):
    """
    Converts YOLO predictions to a dictionary format for easy processing.
    Each bounding box is associated with its width, height, and track ID.
    """
    # Extract coordinates and track IDs
    xywh_coord = yolo_results[0].boxes.xywh.cpu().numpy()
    track_id = yolo_results[0].boxes.id.int().cpu().tolist() if yolo_results[0].boxes.id is not None else np.zeros(xywh_coord.shape[0], dtype=int)
    
    # Create dictionary with coordinates as keys and width, height, and ID as values
    dict_xy_wh_id = {(round(row[0], 2), round(row[1], 2)): {"wh": (row[2], row[3]), "id":track_id[i]} for i, row in enumerate(xywh_coord)}
    return dict_xy_wh_id

def get_norfair_track_results_dict(yolo_results):
    """
    Applies Norfair tracking on YOLO predictions and returns a dictionary of results.
    """
    dict_results = yolo_pred_to_dict(results)
    dict_results_norfair = {}

    # Convert detections to Norfair format and update tracker
    norfair_detections = [Detection(np.array(points)) for points in dict_results.keys()]
    tracked_objects = tracker.update(detections=norfair_detections)

    # Update tracking IDs in the results dictionary
    for tracked_obj in tracked_objects:
        last_point = tuple(tracked_obj.last_detection.points[0])
        
        if last_point in dict_results:
            dict_results_norfair[last_point] = dict_results[last_point]
            dict_results_norfair[last_point]["id"] = tracked_obj.id

    return dict_results_norfair

def draw_game_style_annotations(original_frame, annotations_dictionary, circle_color):
    """
    Draws annotations on the video frame indicating tracked objects with a game-style visualization.
    Each bounding box has a downward-pointing triangle and a semi-ellipse at its bottom.
    """
    frame = original_frame.copy()
    
    # Fixed dimensions for the triangle
    tri_height = 25  # Fixed height of the triangle
    tri_base_half_length = 15  # Half the base length of the triangle
    vertical_offset = 20  # Vertical offset for the triangle above the bounding box

    for center, info in annotations_dictionary.items():
        width, height = info['wh']
        box_id = info['id']
        
        # Calculate the bottom center of the bounding box for the ellipse
        bottom_center = (int(center[0]), int(center[1] + height / 2))
        
        # Define the axes for the ellipse and angle
        ellipse_axes = (int(width / 2), int(height / 10))  # Further reduced height for the semi-ellipse
        ellipse_angle = 0  # Angle of the ellipse
        ellipse_thickness = 4  # Reduced thickness of the ellipse for a neater appearance

        # Draw the bottom half ellipse in blue with the specified thickness
        cv2.ellipse(frame, bottom_center, ellipse_axes, ellipse_angle, 0, 180, circle_color, ellipse_thickness)

        # Calculate the bottom point of the triangle (above the bounding box)
        top_point_triangle = (int(center[0]), int(center[1] - height / 2) - vertical_offset)

        # Triangle points
        p1 = (top_point_triangle[0], top_point_triangle[1] + tri_height)  # Bottom point of the triangle
        p2 = (top_point_triangle[0] - tri_base_half_length, top_point_triangle[1])  # Top-left point
        p3 = (top_point_triangle[0] + tri_base_half_length, top_point_triangle[1])  # Top-right point

        # Draw the filled triangle in white for the ID
        cv2.drawContours(frame, [np.array([p1, p2, p3])], 0, (255, 255, 255), -1)

        # Add the ID text in black, centered in the triangle
        text_size = cv2.getTextSize(str(box_id), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)[0]
        text_x = p1[0] - text_size[0] // 2
        text_y = p1[1] - 2* text_size[1] // 3  # Adjusted for centering text in the triangle
        cv2.putText(frame, str(box_id), (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)

    return frame

def plot_middle_frames(video_paths, super_title="Middle Frames", sub_titles=None):
    """
    Plots middle frames from given videos for comparison.
    """
    # Determine the number of videos
    num_videos = len(video_paths)
    
    # Create subplots
    fig, axs = plt.subplots(1, num_videos, figsize=(5 * num_videos, 5))
    
    # Ensure axs is an array even if there's only one video
    if num_videos == 1:
        axs = [axs]
    
    for i, video_path in enumerate(video_paths):
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error opening video file {video_path}")
            continue
        
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        middle_frame_index = frame_count // 2  # Get the index for the middle frame
        
        # Set the frame position to the middle frame
        cap.set(cv2.CAP_PROP_POS_FRAMES, middle_frame_index)
        ret, frame = cap.read()
        if ret:
            # Convert BGR to RGB
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            axs[i].imshow(frame)
            # Set individual subplot titles
            if sub_titles and i < len(sub_titles):
                axs[i].set_title(sub_titles[i])
            else:
                axs[i].set_title(f"Video {i+1} Middle Frame")
            axs[i].axis('off')
        
        cap.release()
    
    # Set the super title for the entire plot
    plt.suptitle(super_title, fontsize=16, fontweight='bold', y=0.85)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to make room for the super title
    plt.show()

# %% [markdown]
# # Video capture and writer setup

# %%
cap = cv2.VideoCapture(VIDEO_PATH)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4 files
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %% [markdown]
# # Output video writers for each tracker

# %%
out_botsort = cv2.VideoWriter(OUTPUT_BOTSORT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))
out_bytetrack = cv2.VideoWriter(OUTPUT_BYTETRACK_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))
out_norfair = cv2.VideoWriter(OUTPUT_NORFAIR_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))

# %% [markdown]
# # Process each frame of the video

# %%
# Determine the number of frames in the video (for the progress bar)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
progress_bar = tqdm(total=total_frames, desc="Processing Video")

# Initialize norfair tracker
tracker = Tracker(distance_function="euclidean", distance_threshold=100)

while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    if success:
        # Track objects in the frame using different algorithms
        results_botsort = model.track(frame, persist=True, tracker="botsort.yaml")
        results_bytetrack = model.track(frame, persist=True, tracker="bytetrack.yaml")
        results = model(frame, classes=[1,3])

        # Convert results to dictionary of points-dimensions
        dict_results_botsort = yolo_pred_to_dict(results_botsort)
        dict_results_bytetrack = yolo_pred_to_dict(results_bytetrack)
        dict_results_norfair = get_norfair_track_results_dict(results)

        # Visualize the detection and tracking results on the frame
        annotated_frame_botsort = draw_game_style_annotations(frame, dict_results_botsort, circle_color=(0, 0, 255))
        annotated_frame_bytetrack = draw_game_style_annotations(frame, dict_results_bytetrack, circle_color=(0, 255, 0))
        annotated_frame_norfair = draw_game_style_annotations(frame, dict_results_norfair, circle_color=(255, 0, 0))
        
        # Write the frame to the output video
        out_botsort.write(annotated_frame_botsort)
        out_bytetrack.write(annotated_frame_bytetrack)
        out_norfair.write(annotated_frame_norfair)
        
        # Update the progress bar
        progress_bar.update(1)
    else:
        # Break the loop if the end of the video is reached
        break

# Finalize the progress bar
progress_bar.close()

# Release the video capture and writer object, then close all the frames
cap.release()
out_botsort.release()
out_bytetrack.release()
out_norfair.release()
# Out:
# Processing Video:   0%|          | 0/352 [00:00<?, ?it/s]
# 0: 480x800 18 soccer-players, 132.2ms
# Speed: 86.1ms preprocess, 132.2ms inference, 75.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 18 soccer-players, 54.7ms
# Speed: 6.4ms preprocess, 54.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 18 soccer-players, 65.2ms
# Speed: 4.0ms preprocess, 65.2ms inference, 13.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 18 soccer-players, 53.3ms
# Speed: 4.5ms preprocess, 53.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 18 soccer-players, 54.4ms
# Speed: 7.4ms preprocess, 54.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 18 soccer-players, 53.9ms
# Speed: 8.0ms preprocess, 53.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 32.4ms
# Speed: 3.6ms preprocess, 32.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 32.0ms
# Speed: 3.5ms preprocess, 32.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 32.7ms
# Speed: 4.5ms preprocess, 32.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 31.7ms
# Speed: 3.7ms preprocess, 31.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 32.8ms
# Speed: 6.0ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 32.6ms
# Speed: 5.0ms preprocess, 32.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 31.6ms
# Speed: 5.0ms preprocess, 31.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 30.1ms
# Speed: 6.4ms preprocess, 30.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 30.5ms
# Speed: 5.0ms preprocess, 30.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 30.7ms
# Speed: 3.0ms preprocess, 30.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 30.3ms
# Speed: 3.0ms preprocess, 30.3ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 17 soccer-players, 29.6ms
# Speed: 4.0ms preprocess, 29.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 29.7ms
# Speed: 4.2ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 30.0ms
# Speed: 6.8ms preprocess, 30.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 29.1ms
# Speed: 4.0ms preprocess, 29.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 28.6ms
# Speed: 4.0ms preprocess, 28.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 29.1ms
# Speed: 5.5ms preprocess, 29.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 28.8ms
# Speed: 4.0ms preprocess, 28.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 28.6ms
# Speed: 4.0ms preprocess, 28.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 29.1ms
# Speed: 3.0ms preprocess, 29.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 16 soccer-players, 29.1ms
# Speed: 3.0ms preprocess, 29.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 28.5ms
# Speed: 5.4ms preprocess, 28.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 28.6ms
# Speed: 5.0ms preprocess, 28.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 28.3ms
# Speed: 4.3ms preprocess, 28.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 27.7ms
# Speed: 3.0ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 27.4ms
# Speed: 3.6ms preprocess, 27.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 15 soccer-players, 27
ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.7ms
# Speed: 4.0ms preprocess, 22.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.0ms
# Speed: 6.5ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.9ms
# Speed: 3.0ms preprocess, 22.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.9ms
# Speed: 3.9ms preprocess, 22.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.3ms
# Speed: 3.0ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 soccer-players, 22.3ms
# Speed: 3.0ms preprocess, 22.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 soccer-players, 23.1ms
# Speed: 3.0ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 6 soccer-players, 22.3ms
# Speed: 5.5ms preprocess, 22.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.9ms
# Speed: 5.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.8ms
# Speed: 9.6ms preprocess, 21.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.7ms
# Speed: 8.3ms preprocess, 21.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.9ms
# Speed: 3.0ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.2ms
# Speed: 6.6ms preprocess, 22.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.5ms
# Speed: 8.0ms preprocess, 21.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.6ms
# Speed: 5.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.0ms
# Speed: 3.6ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.4ms
# Speed: 3.9ms preprocess, 22.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.0ms
# Speed: 3.7ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.4ms
# Speed: 3.6ms preprocess, 21.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.1ms
# Speed: 5.6ms preprocess, 23.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.3ms
# Speed: 2.5ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.5ms
# Speed: 5.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.7ms
# Speed: 3.5ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.2ms
# Speed: 4.7ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.2ms
# Speed: 4.0ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.6ms
# Speed: 3.8ms preprocess, 13.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.1ms
# Speed: 3.9ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.2ms
# Speed: 3.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.5ms
# Speed: 3.7ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.6ms
# Speed: 4.6ms preprocess, 12.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.5ms
# Speed: 4.7ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.5ms
# Speed: 5.6ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.5ms
# Speed: 3.6ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 12.9ms
# Speed: 2.9ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 16.3ms
# Speed: 4.9ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 16.7ms
# Speed: 4.5ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 16.2ms
# Speed: 16.5ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 16.9ms
# Speed: 3.9ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.3ms
# Speed: 4.1ms preprocess, 24.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.1ms
# Speed: 7.0ms preprocess, 24.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.6ms
# Speed: 4.0ms preprocess, 23.6ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.1ms
# Speed: 3.1ms preprocess, 23.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.3ms
# Speed: 3.6ms preprocess, 24.3ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.8ms
# Speed: 4.0ms preprocess, 24.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.8ms
# Speed: 5.0ms preprocess, 23.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.5ms
# Speed: 3.6ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.6ms
# Speed: 5.0ms preprocess, 24.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.1ms
# Speed: 4.5ms preprocess, 24.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 24.2ms
# Speed: 4.5ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.0ms
# Speed: 4.7ms preprocess, 22.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.3ms
# Speed: 7.7ms preprocess, 23.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.8ms
# Speed: 7.5ms preprocess, 22.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.6ms
# Speed: 4.0ms preprocess, 22.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.2ms
# Speed: 4.1ms preprocess, 22.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.1ms
# Speed: 3.9ms preprocess, 23.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.4ms
# Speed: 4.0ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.3ms
# Speed: 4.7ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.6ms
# Speed: 6.6ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.2ms
# Speed: 2.9ms preprocess, 23.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.4ms
# Speed: 4.3ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.8ms
# Speed: 4.1ms preprocess, 21.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 23.2ms
# Speed: 3.1ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.1ms
# Speed: 3.7ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.0ms
# Speed: 4.6ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.7ms
# Speed: 4.3ms preprocess, 21.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 22.0ms
# Speed: 4.5ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.3ms
# Speed: 4.0ms preprocess, 21.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.9ms
# Speed: 5.6ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.2ms
# Speed: 4.0ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.1ms
# Speed: 4.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.5ms
# Speed: 4.2ms preprocess, 21.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.8ms
# Speed: 3.0ms preprocess, 21.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.8ms
# Speed: 6.0ms preprocess, 21.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.1ms
# Speed: 4.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.3ms
# Speed: 6.7ms preprocess, 21.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.8ms
# Speed: 3.1ms preprocess, 21.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 7 soccer-players, 21.1ms
# Speed: 3.5ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.9ms
# Speed: 2.9ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.0ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 14.2ms
# Speed: 4.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)

# %% [markdown]
# # Display the middle frames of the output videos for comparison

# %%
plot_middle_frames([OUTPUT_BOTSORT_VIDEO_PATH, OUTPUT_BYTETRACK_VIDEO_PATH, OUTPUT_NORFAIR_VIDEO_PATH], 
                   super_title="Outputs comparison different trackers", 
                   sub_titles=["Botsort", "Bytetrack", "Norfair"])
